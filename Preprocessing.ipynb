# %%
# import cv2
# import os
# (we imported libraries)

# %%
#setting the input path and output path

# %%
#input= "C:/Users/MSC1/Desktop/Tensorflow-Object-Detection-API/Base/v1/Tagging/Public/courseworkk/dataset/pics"
#output= "C:/Users/MSC1/Desktop/Tensorflow-Object-Detection-API/Base/v1/Tagging/Public/courseworkk/dataset/neww"
#target_size=(640,640)

# %%
"""
We resize our images and do padding as well since we want our images not to get distorted
and at the same time maintain the aspect ratio. Images were resized to 640*640
"""

# %%
"""
def resize_and_pad_image(input_route, output_route, target_size):
    if os.path.exists(input_route):
        try:
            os.makedirs(output_route)
        except FileExistsError:
            pass
"""

# %%
"""
for filetitle in os.listdir(input_route):
            file_path = os.path.join(input_route, filetitle)
            if os.path.isfile(file_path) and (filetitle.lower().endswith(".jpg") or filetitle.lower().endswith(".jpeg") or filetitle.lower().endswith(".png")):
                img = cv2.imread(file_path)
                if img is not None:
                    original_height, original_width = img.shape[:2]
                    aspect_ratio = original_width / original_height
                    target_width, target_height = target_size
                    if original_width > original_height:
                        new_width = target_width
                        new_height = int(new_width / aspect_ratio)
                    else:
                        new_height = target_height
                        new_width = int(new_height * aspect_ratio)

                    #padding and resizing
                    pad_color = (0, 0, 0)
                    top = (target_height - new_height) // 2
                    bottom = target_height - new_height - top
                    left = (target_width - new_width) // 2
                    right = target_width - new_width - left
                    resized_img = cv2.resize(img, (new_width, new_height))
                    padded_img = cv2.copyMakeBorder(resized_img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=pad_color)
                    output_file_path = os.path.join(output_route, filetitle)
                    cv2.imwrite(output_file_path, padded_img)
                    print(f"Resized and padded: {filetitle}")
                else:
                    print(f"Couldnt read image: {filetitle}")
else:
    print("Input folder path doesnt exist")
# Out:
# Resized and padded: EquusQuagga002.jpg
# Resized and padded: EquusQuagga003.jpg
# Resized and padded: EquusQuagga004.jpg
# Resized and padded: EquusQuagga005.jpg
# Resized and padded: EquusQuagga006.jpg
# Resized and padded: EquusQuagga007.jpg
# Resized and padded: EquusQuagga009.jpg
# Resized and padded: EquusQuagga010.jpg
# Resized and padded: EquusQuagga011.jpg
# Resized and padded: EquusQuagga012.jpg
# Resized and padded: EquusQuagga014.jpg
# Resized and padded: EquusQuagga015.jpg
# Resized and padded: EquusQuagga016.jpg
# Resized and padded: EquusQuagga017.jpg
# Resized and padded: EquusQuagga018.jpg
# Resized and padded: EquusQuagga019.jpg
# Resized and padded: EquusQuagga020.jpg
# Resized and padded: EquusQuagga021.jpg
# Resized and padded: EquusQuagga022.jpg
# Resized and padded: EquusQuagga023.jpg
# Resized and padded: EquusQuagga024.jpg
# Resized and padded: EquusQuagga026.jpg
# Resized and padded: EquusQuagga027.jpg
# Resized and padded: EquusQuagga028.jpg
# ...

# %%
#PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# We are going to run Tensorflow Evaluation Script

# %%
# !python model_main_tf2.py --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --model_dir=training/TF2/training/{PATH_TO_MODEL} --checkpoint_dir=training/TF2/training/{PATH_TO_MODEL} --alsologtostderr
# Out:
# creating index...
# index created!
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.64s).
# Accumulating evaluation results...
# DONE (t=0.27s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.671
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.956
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.765
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.699
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.745
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.750
# ...

# %%
# !tensorboard --logdir=training/TF2/training/{PATH_TO_MODEL}/

#This code will launch Tensorboard.
# we can visualize from Chrome using the default address http://localhost:6006

# %%
"""
Here in Evaluation, we ran an evaluation script to find out the Precision, Recall , Intersection over Union.
Our total loss is 0.2385
DetectionBoxes_Precision/mAP: 0.670514
DetectionBoxes_Precision/mAP@.50IOU: 0.956438
DetectionBoxes_Recall/AR@1: 0.524615
DetectionBoxes_Recall/AR@100 (medium): 0.627593
Loss/BoxClassifierLoss/localization_loss: 0.051318
Loss/BoxClassifierLoss/classification_loss: 0.080164
Finally, we launched Tensorboard.
"""
